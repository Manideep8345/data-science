# %%
import cv2
import numpy as np
name="test3.jpg"
img=cv2.imread(name,1)#cv2.IMREAD_REDUCED_COLOR_4)
imj=cv2.imread(name,0)#,cv2.IMREAD_REDUCED_COLOR_4)
iar=np.asarray(imj)
r=0;x=0;y=0;col=50
for eachrow in iar:
    y=0
    for pi in eachrow:
        
        
        if(pi<=50):
            #pi[0]>250 or pi[1]>250 or pi[2]>250 ):
            cv2.line(img,(y,x),(y,x),(col,col,col),1)
            #img[x][y]=[255,255,255]
            #print pi,#print y#
            #r=r+1
        elif(pi<=100):
            cv2.line(img,(y,x),(y,x),(100,100,100),1)
        elif(pi<=150):
            cv2.line(img,(y,x),(y,x),(150,150,150),1)
        elif(pi<=200):
            cv2.line(img,(y,x),(y,x),(200,200,200),1)
        elif(pi<=255):
            cv2.line(img,(y,x),(y,x),(250,250,250),1)
        y=y+1
    x=x+1;
print "no. of pixles "+str(r)
print "height: "+str(x)
print "width: "+str(y)
'''cv2.imshow('m4k',imj)
cv2.imshow('mk',img)
cv2.imshow('mk1',lap)
cv2.waitKey(0)
cv2.destroyAllWindows()'''
# Out:
# no. of pixles 0
# height: 2304
# width: 4096
# "cv2.imshow('m4k',imj)\ncv2.imshow('mk',img)\n#cv2.imshow('mk1',lap)\ncv2.waitKey(0)\ncv2.destroyAllWindows()"

# %%
import numpy as np
print "season "+str(np.random.randint(1,7))+ " episode "+str(np.random.randint(1,11))
# Out:
# season 1 episode 4

# %%
import first_module as f
f.main()
# Out:
# sexy

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d8e8fca2dc0f> in <module>()
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
#tyui=cv2.imread(name,1)
r#es = np.hstack((tyui,img))
cv2.imwrite('test2_1.jpg',img)
# Out:
# True

# %%
erty=cv2.imread('test.jpg',0)
equ=cv2.equalizeHist(erty)
res = np.hstack((erty,equ))
cv2.imwrite('test_hist_equl.jpg',res)
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
erty=cv2.imread('test2_1.jpg')
tyui=cv2.imread(name)
color=('b','g','r')
fig,(ax1,ax2)=plt.subplots(2,1,sharex=True,figsize=[10,15])
for i, col in enumerate(co):
    histr=cv2.calcHist([img],[i],None,[256],[0,256])
    ax2.plot(histr,color = col)
    ax2.set_xlim([0,256])
    ax2.set_title('changed')
    #cv2.imshow(erty)
for i, col in enumerate(co):
    histr=cv2.calcHist([tyui],[i],None,[256],[0,256])
    ax1.plot(histr,color = col)
    ax1.set_xlim([0,256])
    ax1.set_title('original')
plt.show()

# %%
i=2

# %%
cv2.imwrite("result_countour_"+str(i)+".jpg",img);i+=1

# %%
erty[2000][3500]
# Out:
# array([151, 177, 207], dtype=uint8)

# %%
import cv2,pandas as pd, numpy as np
test=cv2.imread("test3.jpg",0)

# %%
test=cv2.imread("test3.jpg",0)

# %%
df_master=pd.DataFrame()

# %%
df_master=pd.DataFrame({ 0 :test[2303]})
df_master
# Out:
#         0
# 0     130
# 1     114
# 2     102
# 3     101
# 4     107
# 5     108
# 6     116
# 7     107
# 8     105
# 9     109
# 10    119
# 11    122
# 12    126
# 13    117
# 14    130
# 15    141
# 16    145
# 17    139
# 18    136
# 19    137
# 20    137
# 21    132
# 22    138
# 23    159
# 24    179
# 25    190
# 26    194
# 27    192
# 28    196
# 29    196
# ...   ...
# 4066  158
# 4067  153
# 4068  158
# 4069  165
# 4070  163
# 4071  159
# 4072  159
# 4073  164
# 4074  159
# 4075  164
# 4076  169
# 4077  170
# 4078  166
# 4079  150
# 4080  137
# 4081  126
# 4082  117
# 4083  117
# 4084  135
# 4085  146
# 4086  149
# 4087  145
# 4088  163
# 4089  171
# 4090  182
# 4091  178
# 4092  176
# 4093  175
# 4094  178
# 4095  175
#
# [4096 rows x 1 columns]

# %%
j=0
for i in test:
    df34=pd.DataFrame({ j :i})
    df_master=pd.concat([df_master,df34])
    j+=1
df_master

# %%
len(test)
df34
# Out:
#         0
# 0      44
# 1      41
# 2      42
# 3      44
# 4      44
# 5      43
# 6      45
# 7      46
# 8      41
# 9      36
# 10     44
# 11     51
# 12     44
# 13     42
# 14     45
# 15     43
# 16     43
# 17     38
# 18     39
# 19     42
# 20     46
# 21     48
# 22     43
# 23     44
# 24     46
# 25     49
# 26     45
# 27     46
# 28     49
# 29     43
# ...   ...
# 4066  112
# 4067  106
# 4068   96
# 4069   98
# 4070  101
# 4071   97
# 4072   95
# 4073   86
# 4074   89
# 4075   95
# 4076   89
# 4077   86
# 4078   88
# 4079   87
# 4080   91
# 4081   82
# 4082   87
# 4083   88
# 4084   82
# 4085   87
# 4086   79
# 4087   84
# 4088   81
# 4089   79
# 4090   75
# 4091   81
# 4092   83
# 4093   80
# 4094   70
# 4095   68
#
# [4096 rows x 1 columns]

# %%
j
# Out:
# 0
